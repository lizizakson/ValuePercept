# %%
#import libraries
import pandas as pd
import seaborn as sns
import collections
#import matplotlib.pyplot as plt
import numpy as np
import scipy as sc
from scipy import stats
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Load behavioral data

# %%
df = pd.read_csv("/mnt/c/Users/liz/Contacts/Desktop/ValuePercept/Behavior/HCP_behavioralData.csv")
df.shape
df.head()
# Out:
# (1206, 582)
#    Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# 0   100004    S900         Q06      M  22-25             False         0
# 1   100206    S900         Q11      M  26-30              True         1
# 2   100307      Q1         Q01      F  26-30              True         1
# 3   100408      Q3         Q03      M  31-35              True         1
# 4   100610    S900         Q08      M  26-30              True         2
#
#    T2_Count  3T_RS-fMRI_Count  3T_RS-fMRI_PctCompl  ...  Noise_Comp  \
# 0         0                 0                  0.0  ...         5.2
# 1         1                 4                100.0  ...         6.0
# 2         1                 4                100.0  ...         3.6
# 3         1                 4                100.0  ...         2.0
# 4         1                 4                100.0  ...         2.0
#
#    Odor_Unadj  Odor_AgeAdj  PainIntens_RawScore  PainInterf_Tscore  \
# 0      101.12        86.45                  2.0               45.9
# 1      108.79        97.19                  1.0               49.7
# 2      101.12        86.45                  0.0               38.6
# 3      108.79        98.04                  2.0               52.6
# 4      122.25       110.45                  0.0               38.6
#
#    Taste_Unadj  Taste_AgeAdj  Mars_Log_Score  Mars_Errs  Mars_Final
# 0       107.17        105.31            1.80        0.0        1.80
# 1        72.63         72.03            1.84        0.0        1.84
# 2        71.69         71.76            1.76        0.0        1.76
# 3       114.01        113.59            1.76        2.0        1.68
# 4        84.84         85.31            1.92        1.0        1.88
#
# [5 rows x 582 columns]

# %% [markdown]
# # Exclude missing values from the data

# %%
#Detect missing values in the data
#How many Nulls for each field?
null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
type(null_columns)
# Out:
# dMRI_3T_ReconVrs         141
# fMRI_3T_ReconVrs         108
# 7T_fMRI_Mov_Vrs         1022
# QC_Issue                1049
# MRsession_Scanner_3T      93
#                         ...
# Taste_Unadj                6
# Taste_AgeAdj               6
# Mars_Log_Score             8
# Mars_Errs                 11
# Mars_Final                11
# Length: 470, dtype: int64
# pandas.core.indexes.base.Index

# %%
#Delete rows with missing values in specific columns
##PicSeq_AgeAdj - episodic memory task (pic seq memory)
df = df.dropna(subset=['DDisc_AUC_200', 'DDisc_AUC_40K', 'Flanker_AgeAdj', 'Mars_Final', 'CardSort_AgeAdj', 'PicSeq_AgeAdj'])
df.shape
# Out:
# (1191, 582)

# %% [markdown]
# # Exploration of the behavioral tasks

# %% [markdown]
# ## Perceptual task - Mars contrast test

# %%
df['Mars_Final'].describe()

sns.distplot(df['Mars_Final'])
# Out:
# count    1191.000000
# mean        1.822427
# std         0.543786
# min         1.080000
# 25%         1.760000
# 50%         1.800000
# 75%         1.840000
# max        15.000000
# Name: Mars_Final, dtype: float64
# <AxesSubplot:xlabel='Mars_Final'>

# %%
#z-score
df['z_score_mars'] = stats.zscore(df['Mars_Final'])


#Remove outliers (>3 SD)
df = df.loc[df['z_score_mars'].abs()<=3]
#df.describe

# %%
sns.distplot(df['z_score_mars'])
# Out:
# <AxesSubplot:xlabel='z_score_mars'>

# %% [markdown]
# ## Value-based task - delay discounting

# %%
df['DDisc_AUC_200'].describe()

sns.distplot(df['DDisc_AUC_200'])
# Out:
# count    1189.000000
# mean        0.257696
# std         0.205062
# min         0.015692
# 25%         0.104884
# 50%         0.199546
# 75%         0.345770
# max         0.984442
# Name: DDisc_AUC_200, dtype: float64
# <AxesSubplot:xlabel='DDisc_AUC_200'>

# %%
#z-score
df['z_score_DDisc_AUC'] = stats.zscore(df['DDisc_AUC_40K'])


#Remove outliers (>3 SD)
df = df.loc[df['z_score_DDisc_AUC'].abs()<=3]
#df.describe

# %%
sns.distplot(df['z_score_DDisc_AUC'])
# Out:
# <AxesSubplot:xlabel='z_score_DDisc_AUC'>

# %% [markdown]
# ## Perceptual decision-making/selective attention - Flanker task

# %%
df['Flanker_AgeAdj'].describe()

#Scores distribution
sns.distplot(df['Flanker_AgeAdj'])
# Out:
# count    1189.000000
# mean      101.406686
# std        10.125334
# min        69.310000
# 25%        94.780000
# 50%       101.610000
# 75%       108.920000
# max       123.560000
# Name: Flanker_AgeAdj, dtype: float64
# <AxesSubplot:xlabel='Flanker_AgeAdj'>

# %%
#z-score
df['z_score_Flanker'] = stats.zscore(df['Flanker_AgeAdj'])


#Remove outliers (>3 SD)
df = df.loc[df['z_score_Flanker'].abs()<=3]
#df.describe

sns.distplot(df['z_score_Flanker'])
# Out:
# <AxesSubplot:xlabel='z_score_Flanker'>

# %%
#Correlation between Flanker task and Delay Discount task
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

x = df['Flanker_AgeAdj']
y = df['DDisc_AUC_40K']

#sc.stats.pearsonr(x, y)

plt.scatter(x, y)
plt.show()

sns.regplot(x, y)
# Out:
# <AxesSubplot:xlabel='Flanker_AgeAdj', ylabel='DDisc_AUC_40K'>

# %%
#There is no significant behavioral corr between Flanker task and Delay Discount task
sc.stats.pearsonr(x, y)
# Out:
# (0.038321813100404924, 0.187225000701237)

# %% [markdown]
# # Selective attention/Executive Function/Cognitive Flexibility - CardSort task

# %%
df['CardSort_AgeAdj'].describe()

#Scores distribution
sns.distplot(df['CardSort_AgeAdj'])
# Out:
# count    1186.000000
# mean      101.979325
# std         9.998371
# min        55.390000
# 25%        95.297500
# 50%       101.930000
# 75%       109.667500
# max       122.650000
# Name: CardSort_AgeAdj, dtype: float64
# <AxesSubplot:xlabel='CardSort_AgeAdj'>

# %%
#z-score
df['z_score_CardSort'] = stats.zscore(df['CardSort_AgeAdj'])


#Remove outliers (>3 SD)
df = df.loc[df['z_score_CardSort'].abs()<=3]
#df.describe

sns.distplot(df['z_score_CardSort'])
# Out:
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <AxesSubplot:xlabel='z_score_CardSort'>

# %%
#Correlation between Flanker task and CardSort task
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

x = df['Flanker_AgeAdj']
y = df['CardSort_AgeAdj']

#sc.stats.pearsonr(x, y)
sns.regplot(x, y)
# Out:
# <AxesSubplot:xlabel='Flanker_AgeAdj', ylabel='CardSort_AgeAdj'>

# %%
#There is a significant behavioral corr between Flanker task and Card Sort task
sc.stats.pearsonr(x, y)
# Out:
# (0.5288138794096645, 5.461034434074862e-86)

# %% [markdown]
# ## Comparison between z_scores of Mars Contrast and Delay discount

# %%
#correlation
x = df['z_score_DDisc_AUC']
y = df['z_score_mars']
sc.stats.pearsonr(x, y)
# Out:
# (0.07355122617970813, 0.01149388382450561)

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

x = df['z_score_DDisc_AUC']
y = df['z_score_mars']

#sc.stats.pearsonr(x, y)

plt.scatter(x, y)
plt.show()

# %%
#Devide the subjects into 4 groups according to the z-scores in both variables
df['GroupType'] = ""

for index, row in df.iterrows():
    if row['z_score_mars'] < 0.0 and row['z_score_DDisc_AUC'] < 0.0:
        df['GroupType'][index] = 0
        #print(row)
    elif row['z_score_mars'] < 0 and row['z_score_DDisc_AUC'] > 0:
        df['GroupType'][index] = 1
    elif row['z_score_mars'] >= 0 and row['z_score_DDisc_AUC'] >= 0:
        df['GroupType'][index] = 2
    elif row['z_score_mars'] >= 0 and row['z_score_DDisc_AUC'] <= 0:
        df['GroupType'][index]= 3

df['GroupType'].unique()
# Out:
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# array([0, 3, 2, 1], dtype=object)

# %%
#validate if the classification to groups is correct
df.head(10)
# Out:
#    Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# 0   100004    S900         Q06      M  22-25             False         0
# 1   100206    S900         Q11      M  26-30              True         1
# 2   100307      Q1         Q01      F  26-30              True         1
# 3   100408      Q3         Q03      M  31-35              True         1
# 4   100610    S900         Q08      M  26-30              True         2
# 5   101006    S500         Q06      F  31-35              True         2
# 6   101107    S500         Q06      M  22-25              True         2
# 7   101208   S1200         Q12      F  31-35             False         0
# 8   101309    S500         Q06      M  26-30              True         1
# 9   101410    S500         Q06      M  26-30             False         2
#
#    T2_Count  3T_RS-fMRI_Count  3T_RS-fMRI_PctCompl  ...  Taste_Unadj  \
# 0         0                 0                  0.0  ...       107.17
# 1         1                 4                100.0  ...        72.63
# 2         1                 4                100.0  ...        71.69
# 3         1                 4                100.0  ...       114.01
# 4         1                 4                100.0  ...        84.84
# 5         2                 4                100.0  ...       123.80
# 6         2                 4                100.0  ...       134.65
# 7         0                 0                  0.0  ...       105.57
# 8         1                 4                100.0  ...       106.39
# 9         1                 2                 50.0  ...        73.86
#
#    Taste_AgeAdj  Mars_Log_Score  Mars_Errs  Mars_Final  z_score_mars  \
# 0        105.31            1.80        0.0        1.80     -0.041259
# 1         72.03            1.84        0.0        1.84      0.032330
# 2         71.76            1.76        0.0        1.76     -0.114848
# 3        113.59            1.76        2.0        1.68     -0.262027
# 4         85.31            1.92        1.0        1.88      0.105920
# 5        123.31            1.80        0.0        1.80     -0.041259
# 6        131.38            1.84        0.0        1.84      0.032330
# 7        102.32            1.92        0.0        1.92      0.179509
# 8        104.39            1.80        0.0        1.80     -0.041259
# 9         71.78            1.80        0.0        1.80     -0.041259
#
#    z_score_DDisc_AUC  z_score_Flanker  z_score_CardSort  GroupType
# 0          -1.521743         0.950647         -1.334713          0
# 1          -1.582579         1.502122          0.296241          3
# 2          -0.670943         0.043798          0.794532          0
# 3          -0.287765         1.199508         -0.121003          0
# 4           1.272186         1.266202          1.320839          2
# 5           0.973453        -0.908841         -0.768382          1
# 6           0.280646        -0.524600          0.371284          2
# 7           1.095125        -1.692255         -1.955075          2
# 8           1.554576         0.190128         -1.595865          1
# 9          -0.580597        -0.087601          0.486352          0
#
# [10 rows x 587 columns]

# %%
#Show performance in Flanker task according to the 4 groups
FT = df.groupby(['GroupType'])['Flanker_AgeAdj'].mean()
print(FT)
FT.plot(kind='bar')
# Out:
# GroupType
# 0    101.637535
# 1    101.269139
# 2    102.448298
# 3    100.710000
# Name: Flanker_AgeAdj, dtype: float64
# <AxesSubplot:xlabel='GroupType'>

# %%
#from: https://www.pythonfordatascience.org/anova-python/
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols('Flanker_AgeAdj ~ C(GroupType)', data=df).fit()
aov_table = sm.stats.anova_lm(model, typ=2)
aov_table
# Out:
#                      sum_sq      df         F    PR(>F)
# C(GroupType)     304.798985     3.0  1.015209  0.385046
# Residual      117691.286675  1176.0       NaN       NaN

# %%
#Create a coloumn that compares between the two z-scores
#df['z_score_compare'] = df['z_score_mars']-df['z_score_DD200']

df['z_score_compare'] = ""

for index, row in df.iterrows():
    df['z_score_compare'][index] = abs(row['z_score_mars'] - row['z_score_DDisc_AUC'])
    
df['z_score_compare']

df.head()
# Out:
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# 0         1.48048
# 1         1.61491
# 2        0.556095
# 3       0.0257385
# 4         1.16627
#           ...
# 1201      1.57397
# 1202      1.62947
# 1203     0.203905
# 1204     0.539338
# 1205     0.465376
# Name: z_score_compare, Length: 1180, dtype: object
#    Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# 0   100004    S900         Q06      M  22-25             False         0
# 1   100206    S900         Q11      M  26-30              True         1
# 2   100307      Q1         Q01      F  26-30              True         1
# 3   100408      Q3         Q03      M  31-35              True         1
# 4   100610    S900         Q08      M  26-30              True         2
#
#    T2_Count  3T_RS-fMRI_Count  3T_RS-fMRI_PctCompl  ...  Taste_AgeAdj  \
# 0         0                 0                  0.0  ...        105.31
# 1         1                 4                100.0  ...         72.03
# 2         1                 4                100.0  ...         71.76
# 3         1                 4                100.0  ...        113.59
# 4         1                 4                100.0  ...         85.31
#
#    Mars_Log_Score  Mars_Errs  Mars_Final  z_score_mars  z_score_DDisc_AUC  \
# 0            1.80        0.0        1.80     -0.041259          -1.521743
# 1            1.84        0.0        1.84      0.032330          -1.582579
# 2            1.76        0.0        1.76     -0.114848          -0.670943
# 3            1.76        2.0        1.68     -0.262027          -0.287765
# 4            1.92        1.0        1.88      0.105920           1.272186
#
#    z_score_Flanker  z_score_CardSort  GroupType  z_score_compare
# 0         0.950647         -1.334713          0          1.48048
# 1         1.502122          0.296241          3          1.61491
# 2         0.043798          0.794532          0         0.556095
# 3         1.199508         -0.121003          0        0.0257385
# 4         1.266202          1.320839          2          1.16627
#
# [5 rows x 588 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt

x = df['Flanker_AgeAdj']
y = df['z_score_compare']

plt.scatter(x, y)
plt.show()

sns.regplot(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-850925e5db97> in <module>
#       8 plt.show()
#       9
# ---> 10 sns.regplot(x, y)
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     815     scatter_kws["marker"] = marker
#     816     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 817     plotter.plot(ax, scatter_kws, line_kws)
#     818     return ax
#     819
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/regression.py in plot(self, ax, scatter_kws, line_kws)
#     367
#     368         if self.fit_reg:
# --> 369             self.lineplot(ax, line_kws)
#     370
#     371         # Label the axes
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/regression.py in lineplot(self, ax, kws)
#     422         line.sticky_edges.x[:] = edges  # Prevent mpl from adding margin
#     423         if err_bands is not None:
# --> 424             ax.fill_between(grid, *err_bands, facecolor=fill_color, alpha=.15)
#     425
#     426
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1429     def inner(ax, *args, data=None, **kwargs):
#    1430         if data is None:
# -> 1431             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1432
#    1433         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5301         return self._fill_between_x_or_y(
#    5302             "x", x, y1, y2,
# -> 5303             where=where, interpolate=interpolate, step=step, **kwargs)
#    5304
#    5305     fill_between.__doc__ = _fill_between_x_or_y.__doc__.format(
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5203         ind = ma.masked_invalid(getattr(self, f"convert_{ind_dir}units")(ind))
#    5204         dep1 = ma.masked_invalid(
# -> 5205             getattr(self, f"convert_{dep_dir}units")(dep1))
#    5206         dep2 = ma.masked_invalid(
#    5207             getattr(self, f"convert_{dep_dir}units")(dep2))
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/ma/core.py in masked_invalid(a, copy)
#    2375         cls = type(a)
#    2376     else:
# -> 2377         condition = ~(np.isfinite(a))
#    2378         cls = MaskedArray
#    2379     result = a.view(cls)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
#correlation
#Negative means that the similar the score in Mars and DD tasks (smaller z_compare), the higher the score in Flanker task
sc.stats.pearsonr(x, y)
# Out:
# (-0.04111366795609391, 0.15812645731140998)

# %%
df['z_score_compare'].describe()

#Scores distribution
sns.distplot(df['z_score_compare'])
# Out:
# count     1180.000000
# unique    1106.000000
# top          1.716599
# freq         9.000000
# Name: z_score_compare, dtype: float64
# <AxesSubplot:xlabel='z_score_compare'>

# %% [markdown]
# ## Comparison between z_scores of Flanker task and Delay discount

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

x = df['z_score_DDisc_AUC']
y = df['z_score_Flanker']

#sc.stats.pearsonr(x, y)

plt.scatter(x, y)
plt.show()

sns.regplot(x, y)
# Out:
# <AxesSubplot:xlabel='z_score_DDisc_AUC', ylabel='z_score_Flanker'>

# %%
sc.stats.pearsonr(x, y)
# Out:
# (0.03654958182483244, 0.20962113048037861)

# %%
#Devide the subjects into 4 groups according to the z-scores in both variables
df['GroupType_f'] = ""

for index, row in df.iterrows():
    if row['z_score_Flanker'] < 0.0 and row['z_score_DDisc_AUC'] < 0.0:
        df['GroupType_f'][index] = 0
        #print(row)
    elif row['z_score_Flanker'] < 0 and row['z_score_DDisc_AUC'] > 0:
        df['GroupType_f'][index] = 1
    elif row['z_score_Flanker'] >= 0 and row['z_score_DDisc_AUC'] >= 0:
        df['GroupType_f'][index] = 2
    elif row['z_score_Flanker'] >= 0 and row['z_score_DDisc_AUC'] <= 0:
        df['GroupType_f'][index]= 3

df['GroupType_f'].unique()
# Out:
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([3, 2, 1, 0], dtype=object)

# %%
#validate if the classification to groups is correct
df.head(10)
# Out:
#    Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# 0   100004    S900         Q06      M  22-25             False         0
# 1   100206    S900         Q11      M  26-30              True         1
# 2   100307      Q1         Q01      F  26-30              True         1
# 3   100408      Q3         Q03      M  31-35              True         1
# 4   100610    S900         Q08      M  26-30              True         2
# 5   101006    S500         Q06      F  31-35              True         2
# 6   101107    S500         Q06      M  22-25              True         2
# 7   101208   S1200         Q12      F  31-35             False         0
# 8   101309    S500         Q06      M  26-30              True         1
# 9   101410    S500         Q06      M  26-30             False         2
#
#    T2_Count  3T_RS-fMRI_Count  3T_RS-fMRI_PctCompl  ...  Mars_Log_Score  \
# 0         0                 0                  0.0  ...            1.80
# 1         1                 4                100.0  ...            1.84
# 2         1                 4                100.0  ...            1.76
# 3         1                 4                100.0  ...            1.76
# 4         1                 4                100.0  ...            1.92
# 5         2                 4                100.0  ...            1.80
# 6         2                 4                100.0  ...            1.84
# 7         0                 0                  0.0  ...            1.92
# 8         1                 4                100.0  ...            1.80
# 9         1                 2                 50.0  ...            1.80
#
#    Mars_Errs  Mars_Final  z_score_mars  z_score_DDisc_AUC  z_score_Flanker  \
# 0        0.0        1.80     -0.041259          -1.521743         0.950647
# 1        0.0        1.84      0.032330          -1.582579         1.502122
# 2        0.0        1.76     -0.114848          -0.670943         0.043798
# 3        2.0        1.68     -0.262027          -0.287765         1.199508
# 4        1.0        1.88      0.105920           1.272186         1.266202
# 5        0.0        1.80     -0.041259           0.973453        -0.908841
# 6        0.0        1.84      0.032330           0.280646        -0.524600
# 7        0.0        1.92      0.179509           1.095125        -1.692255
# 8        0.0        1.80     -0.041259           1.554576         0.190128
# 9        0.0        1.80     -0.041259          -0.580597        -0.087601
#
#    z_score_CardSort  GroupType  z_score_compare  GroupType_f
# 0         -1.334713          0          1.48048            3
# 1          0.296241          3          1.61491            3
# 2          0.794532          0         0.556095            3
# 3         -0.121003          0        0.0257385            3
# 4          1.320839          2          1.16627            2
# 5         -0.768382          1          1.01471            1
# 6          0.371284          2         0.248315            1
# 7         -1.955075          2         0.915616            1
# 8         -1.595865          1          1.59583            2
# 9          0.486352          0         0.539338            0
#
# [10 rows x 589 columns]

# %%
#Plot the classification
from  matplotlib import pyplot
import seaborn
seaborn.set(style='ticks')

fg = seaborn.FacetGrid(data=df, hue='GroupType_f', aspect=1.61)
fg.map(pyplot.scatter, 'z_score_Flanker', 'z_score_DDisc_AUC').add_legend()

# %%
#Create a coloumn that compares between the two z-scores
#df['z_score_compare'] = df['z_score_mars']-df['z_score_DD200']

df['z_score_compare_f'] = ""

for index, row in df.iterrows():
    df['z_score_compare_f'][index] = abs(row['z_score_Flanker'] - row['z_score_DDisc_AUC'])
    
df['z_score_compare_f']
# Out:
# /home/lizakson/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# 0        2.47239
# 1         3.0847
# 2       0.714741
# 3        1.48727
# 4       0.005984
#           ...
# 1201     3.11628
# 1202      1.0169
# 1203     1.26972
# 1204    0.771217
# 1205    0.618144
# Name: z_score_compare_f, Length: 1180, dtype: object

# %%
df.head(10)
# Out:
#    Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# 0   100004    S900         Q06      M  22-25             False         0
# 1   100206    S900         Q11      M  26-30              True         1
# 2   100307      Q1         Q01      F  26-30              True         1
# 3   100408      Q3         Q03      M  31-35              True         1
# 4   100610    S900         Q08      M  26-30              True         2
# 5   101006    S500         Q06      F  31-35              True         2
# 6   101107    S500         Q06      M  22-25              True         2
# 7   101208   S1200         Q12      F  31-35             False         0
# 8   101309    S500         Q06      M  26-30              True         1
# 9   101410    S500         Q06      M  26-30             False         2
#
#    T2_Count  3T_RS-fMRI_Count  3T_RS-fMRI_PctCompl  ...  Mars_Errs  \
# 0         0                 0                  0.0  ...        0.0
# 1         1                 4                100.0  ...        0.0
# 2         1                 4                100.0  ...        0.0
# 3         1                 4                100.0  ...        2.0
# 4         1                 4                100.0  ...        1.0
# 5         2                 4                100.0  ...        0.0
# 6         2                 4                100.0  ...        0.0
# 7         0                 0                  0.0  ...        0.0
# 8         1                 4                100.0  ...        0.0
# 9         1                 2                 50.0  ...        0.0
#
#    Mars_Final  z_score_mars  z_score_DDisc_AUC  z_score_Flanker  \
# 0        1.80     -0.041259          -1.521743         0.950647
# 1        1.84      0.032330          -1.582579         1.502122
# 2        1.76     -0.114848          -0.670943         0.043798
# 3        1.68     -0.262027          -0.287765         1.199508
# 4        1.88      0.105920           1.272186         1.266202
# 5        1.80     -0.041259           0.973453        -0.908841
# 6        1.84      0.032330           0.280646        -0.524600
# 7        1.92      0.179509           1.095125        -1.692255
# 8        1.80     -0.041259           1.554576         0.190128
# 9        1.80     -0.041259          -0.580597        -0.087601
#
#    z_score_CardSort  GroupType  z_score_compare  GroupType_f  \
# 0         -1.334713          0          1.48048            3
# 1          0.296241          3          1.61491            3
# 2          0.794532          0         0.556095            3
# 3         -0.121003          0        0.0257385            3
# 4          1.320839          2          1.16627            2
# 5         -0.768382          1          1.01471            1
# 6          0.371284          2         0.248315            1
# 7         -1.955075          2         0.915616            1
# 8         -1.595865          1          1.59583            2
# 9          0.486352          0         0.539338            0
#
#    z_score_compare_f
# 0            2.47239
# 1             3.0847
# 2           0.714741
# 3            1.48727
# 4           0.005984
# 5            1.88229
# 6           0.805246
# 7            2.78738
# 8            1.36445
# 9           0.492996
#
# [10 rows x 590 columns]

# %%
df['z_score_compare_f'].describe()

#Scores distribution
sns.distplot(df['z_score_compare_f'])
# Out:
# count     1180.000000
# unique    1178.000000
# top          0.928759
# freq         2.000000
# Name: z_score_compare_f, dtype: float64
# <AxesSubplot:xlabel='z_score_compare_f'>

# %%
#Save to csv
df.to_csv('HCP_behavior_includeZscores_V2.csv')
